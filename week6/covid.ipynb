# %%
# library import
import pandas as pd
import folium
import matplotlib.pyplot as plt

# %%
# import the csv file
df = pd.read_csv('COVID-19.csv')
# Out:
# C:\Users\Touam\AppData\Local\Temp\ipykernel_8448\936723640.py:2: DtypeWarning: Columns (1,2,3,4,15,16,17,31,32,42,43,53) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('COVID-19.csv')

# %%
df
# Out:
#             通し 厚労省NO 無症状病原体保有者   国内 チャーター便   年代  性別         確定日         発症日
# 0            1    1        NaN  A-1    NaN  30   男性   1/15/2020    1/3/2020  \
# 1            2    2        NaN  A-2    NaN  40   男性   1/24/2020   1/14/2020
# 2            3    3        NaN  A-3    NaN  30   女性   1/25/2020   1/21/2020
# 3            4    4        NaN  A-4    NaN  40   男性   1/26/2020   1/23/2020
# 4            5    5        NaN  A-5    NaN  40   男性   1/28/2020   1/22/2020
# ...        ...   ...       ...  ...    ...  ...  ..         ...         ...
# 133169  133170   NaN       NaN  NaN    NaN   30  男性  11/30/2020         NaN
# 133170  133171   NaN       NaN  NaN    NaN   70  女性  11/30/2020  11/29/2020
# 133171  133172   NaN       NaN  NaN    NaN   70  女性  11/30/2020  11/25/2020
# 133172  133173   NaN       NaN  NaN    NaN   50  男性  11/30/2020  11/30/2020
# 133173  133174   NaN       NaN  NaN    NaN   60  女性  11/30/2020  11/23/2020
#
# ...

# %%
df.shape
# Out:
# (133174, 54)
